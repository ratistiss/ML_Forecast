# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import pickle

# %%
records = pd.read_csv('curiosity.csv')
print('records:   ', len(records))
records.head(5)
# Out:
# records:    1867
#      id terrestrial_date  min_temp  max_temp  pressure
# 0  1895       2018-02-27       -77       -10       727
# 1  1893       2018-02-26       -77       -10       728
# 2  1894       2018-02-25       -76       -16       729
# 3  1892       2018-02-24       -77       -13       729
# 4  1889       2018-02-23       -78       -18       730

# %%
y = records[['min_temp']]
x = records[['max_temp','pressure']]

# %%
linear_regress = LinearRegression()

# %%
linear_regress.fit(x.values,y.values)
print(linear_regress.coef_)
# Out:
# [[0.42391286 0.01620003]]

# %%
y_pred = linear_regress.predict(x.values)

# %%
print(y_pred)
# Out:
# [[-76.90471914]
#  [-76.88851911]
#  [-79.41579623]
#  ...
#  [-80.06922161]
#  [-77.11803164]
#  [-79.25379595]]

# %%
plt.plot(y_pred)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
mean_squared_error(y, y_pred)
# Out:
# 9.00811718912413

# %%
print(linear_regress.predict([[-75, 727]]))
# Out:
# [[-104.45905482]]

# %%
pickle.dump(linear_regress, open('/Users/manderson/Documents/the-weatherman-mars/ML_forecast/low_predictions.pikl', 'wb'))

# %%
model = pickle.load(open('/Users/manderson/Documents/the-weatherman-mars/ML_forecast/low_predictions.pikl', 'rb'))
result_val = model.score(x, y)

# %%
print(result_val)
model.predict([[-73, 740]])
# Out:
# 0.7024948952244934
# array([[-103.40062875]])
